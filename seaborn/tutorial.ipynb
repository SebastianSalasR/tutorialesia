# %% [markdown]
# # Seaborn tutorial

# %% [markdown]
# ## Setup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Import data

# %%
print(sns.get_dataset_names()) # Get the datasets that come with seaborn
crash_df = sns.load_dataset('car_crashes')
crash_df
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# ...

# %% [markdown]
# # Distribution plots

# %% [markdown]
# ## Distribution plot

# %%
sns.displot(crash_df["not_distracted"], kde=True)

# %% [markdown]
# ## Joint plot

# %% [markdown]
# Joinplot is a combination plot that shows the relationship between two variables along with their individual distributions. This type of graph is useful for analyzing correlations and the joint distribution of data.
#
# https://seaborn.pydata.org/generated/seaborn.jointplot.html

# %%
sns.jointplot(x="speeding", y="alcohol", data=crash_df, kind="reg")

# %% [markdown]
# ## KDE plot

# %% [markdown]
# Kernel Density Estimation (KDE) is a non-parametric way to estimate a probability density function (PDF) of a dataset. It smooths out the distribution by placing small bumps (kernels) at each data point and summing them.
#
# More about kde plot: https://seaborn.pydata.org/generated/seaborn.kdeplot.html

# %%
sns.kdeplot(crash_df["alcohol"], fill=True)
# Out:
# <Axes: xlabel='alcohol', ylabel='Density'>

# %% [markdown]
# # Pair plots
#
# It's going to plot the relationship across the entire dataframe numerical values

# %%
sns.pairplot(crash_df)

# %%
tips_df = sns.load_dataset('tips')
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#sns.pairplot(tips_df)
sns.pairplot(tips_df, hue="sex", palette="Oranges")

# %% [markdown]
# # Rug plot
#
# It's going to plot a single column of data points in a dataframe as sticks and you'll see more dense number of lines where the amount are more common

# %%
sns.rugplot(tips_df["tip"])
# Out:
# <Axes: xlabel='tip'>

# %% [markdown]
# ## Styling
#
# set style: https://seaborn-pydata-org.translate.goog/generated/seaborn.set_style.html?_x_tr_sl=en&_x_tr_tl=es&_x_tr_hl=es&_x_tr_pto=tc
#
# set context: https://seaborn.pydata.org/generated/seaborn.set_context.html

# %%
#sns.set_style("white")
#sns.set_style("darkgrid")
sns.set_style("ticks")
plt.figure(figsize=(8,4))

sns.set_context("paper", font_scale=1.5)
sns.jointplot(x="speeding", y="alcohol", data=crash_df, kind="reg")
sns.despine(left=True, bottom=True)

# %% [markdown]
# # Categorical Plots

# %% [markdown]
# ## Bar plots

# %%
sns.barplot(x="sex", y="total_bill", data=tips_df)# The default estimator is the mean
#sns.barplot(x="sex", y="total_bill", data=tips_df, estimator=np.median)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# ## Count plot
#
# Is a bar plot, but the estimator is the number of occurrences.

# %%
sns.countplot(x="sex", data=tips_df, hue="sex")
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# ## Box plot

# %%
sns.boxplot(x="day", y="total_bill", data=tips_df, hue="sex")
plt.legend(loc=1)# Move the legend to the upper right corner

# %% [markdown]
# ## Violin plot

# %%
sns.violinplot(x="day", y="total_bill", data=tips_df, hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## Strip plot
#
# Basically it's going to draw a scatter plot representing all the different data points where one variable is categorical.

# %%
sns.stripplot(x="day", y="total_bill", data=tips_df, hue="sex", dodge=True)# Dodge is going to separate the points for each category
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## Swarm plot
#
# Swarm plot it's like a strip plot but points are going to be fixed so they don't overlap

# %%
#sns.violinplot(x="day", y="total_bill", data=tips_df)
#sns.swarmplot(x="day", y="total_bill", data=tips_df, color="white")
sns.swarmplot(x="day", y="total_bill", data=tips_df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Palettes
#
# Available pallettes: https://matplotlib.org/stable/users/explain/colors/colormaps.html | https://seaborn.pydata.org/tutorial/color_palettes.html

# %%
plt.Figure(figsize=(8,4))
sns.set_style("dark")
sns.set_context("talk")
sns.stripplot(x="day", y="total_bill", data=tips_df, hue="sex", dodge=True, palette="viridis")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Matrix Plots

# %% [markdown]
# ## Heatmaps

# %%
sns.set_context("paper", font_scale=1.4)

crash_mx = crash_df.drop(columns=["abbrev"]).corr() # Basically this is going to tell you how  influential a variable is going to be on the results
sns.heatmap(crash_mx, annot=True, cmap="Blues")
# Out:
# <Axes: >

# %%
flights = sns.load_dataset('flights') # you cant stablish a correlation since the dataset has a index column
flights = flights.pivot_table(index="month", columns="year", values="passengers")
flights
# Out:
# /tmp/ipykernel_7983/1418235233.py:2: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   flights = flights.pivot_table(index="month", columns="year", values="passengers")
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# Jul    148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0  491.0
# ...

# %%
sns.heatmap(flights, cmap="Blues", linecolor="white", linewidth=1)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %% [markdown]
# ## Cluster Map
#
# The distance between points are going to be calculated an then the closest are going to be joined and this is going to continue for the next closest and then its going to compare the columns and the rows of our heatmap

# %%
iris = sns.load_dataset('iris')
species = iris.pop("species")
sns.clustermap(iris, cmap="coolwarm", standard_scale=1)

# %%
sns.clustermap(flights, cmap="coolwarm", standard_scale=1)

# %% [markdown]
# ## Pairgrid
#
# It's like a pair plot but with much more control over what plots and what data shows up where

# %%
iris = sns.load_dataset('iris')
iris_g = sns.PairGrid(iris, hue="species")
# iris_g.map(plt.scatter)
iris_g.map_diag(sns.histplot)
iris_g.map_offdiag(sns.scatterplot)

# %%
iris_g = sns.PairGrid(iris, hue="species")
iris_g.map_upper(sns.scatterplot)
iris_g.map_lower(sns.kdeplot)

# %%
iris_g = sns.PairGrid(iris, hue="species",
                      x_vars=["sepal_length", "sepal_width"],
                      y_vars=["petal_length", "petal_width"])
iris_g.map(sns.scatterplot)
iris_g.add_legend()

# %% [markdown]
# # Facet Grid
#
# You''ll be able to print multiple plots in our grid in which you'll be able to define columns and rows

# %%
tips_fg = sns.FacetGrid(tips_df, col="time", row="smoker")
tips_fg.map(sns.scatterplot, "total_bill", "tip")
