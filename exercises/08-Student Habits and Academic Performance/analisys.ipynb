# %% [markdown]
# # Students habits performance

# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Load data

# %%
df = pd.read_csv("./data/enhanced_student_habits_performance_dataset.csv")

df
# Out:
#        student_id  age  gender             major  study_hours_per_day  \
# 0          100000   26    Male  Computer Science             7.645367
# 1          100001   28    Male              Arts             5.700000
# 2          100002   17    Male              Arts             2.400000
# 3          100003   27   Other        Psychology             3.400000
# 4          100004   25  Female          Business             4.700000
# ...           ...  ...     ...               ...                  ...
# 79995      179995   16    Male       Engineering             3.700000
# 79996      179996   16  Female          Business             1.200000
# 79997      179997   26  Female              Arts             4.100000
# 79998      179998   23   Other           Biology             3.800000
# 79999      179999   25   Other       Engineering             3.000000
#
#        social_media_hours  netflix_hours part_time_job  attendance_percentage  \
# ...

# %% [markdown]
# # Data analysis

# %% [markdown]
# ## General info

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        student_id  age  gender             major  study_hours_per_day  \
# 0          100000   26    Male  Computer Science             7.645367
# 1          100001   28    Male              Arts             5.700000
# 2          100002   17    Male              Arts             2.400000
# 3          100003   27   Other        Psychology             3.400000
# 4          100004   25  Female          Business             4.700000
# ...           ...  ...     ...               ...                  ...
# 79995      179995   16    Male       Engineering             3.700000
# 79996      179996   16  Female          Business             1.200000
# 79997      179997   26  Female              Arts             4.100000
# 79998      179998   23   Other           Biology             3.800000
# 79999      179999   25   Other       Engineering             3.000000
#
#        social_media_hours  netflix_hours part_time_job  attendance_percentage  \
# ...

# %%
# Crear figura y ejes
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# Plot 1: Learning Style Distribution
sns.countplot(data=df, x="learning_style", hue="learning_style", legend=False, palette="viridis", ax=axes[0, 0])
axes[0, 0].set_title("Learning Style Distribution")
axes[0, 0].set_xlabel("Learning Style")
axes[0, 0].set_ylabel("Count")
axes[0, 0].tick_params(axis='x', rotation=45)

# Plot 2: Major Distribution
sns.countplot(data=df, x="major", hue="major", legend=False, palette="viridis", ax=axes[0, 1])
axes[0, 1].set_title("Major Distribution")
axes[0, 1].set_xlabel("Major")
axes[0, 1].set_ylabel("Count")
axes[0, 1].tick_params(axis='x', rotation=45)

# Plot 3: Age Distribution
sns.countplot(data=df, x="age", hue="age", legend=False, palette="viridis", ax=axes[1, 0])
axes[1, 0].set_title("Age Distribution")
axes[1, 0].set_xlabel("Age")
axes[1, 0].set_ylabel("Count")

# Plot 4: Semester Distribution
sns.countplot(data=df, x="semester", hue="semester", legend=False, palette="viridis", ax=axes[1, 1])
axes[1, 1].set_title("Semester Distribution")
axes[1, 1].set_xlabel("Semester")
axes[1, 1].set_ylabel("Count")

# Ajustar diseño
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Lifestyle factors

# %%
fig, axes=plt.subplots(2,2, figsize=(20,13))

sns.histplot(data=df, x="sleep_hours", hue="sleep_hours", palette="flare", legend=False, ax=axes[0,0])
axes[0, 0].set_title("Sleep hours")
axes[0, 0].set_xlabel("sleep hours")
axes[0, 0].set_ylabel("Count")

sns.histplot(data=df, x="exercise_frequency", hue="exercise_frequency", palette="flare", legend=False, ax=axes[0,1])
axes[0, 1].set_title("Exercise frequency")
axes[0, 1].set_xlabel("exercise frequency")
axes[0, 1].set_ylabel("Count")

sns.countplot(data=df, x="diet_quality", hue="diet_quality", palette="flare", legend=False, ax=axes[1,0])
axes[1, 0].set_title("Diet quality")
axes[1, 0].set_xlabel("Diet")
axes[1, 0].set_ylabel("Count")

fig.delaxes(axes[1,1])

# %% [markdown]
# ## Exam scores distribution

# %%
sns.histplot(data=df, x="exam_score", hue="exam_score",palette="flare", legend=False)
# Out:
# <Axes: xlabel='exam_score', ylabel='Count'>

# %% [markdown]
# ## Scores by gender

# %%
sns.violinplot(data=df, x="gender", y="exam_score", hue="gender")
# Out:
# <Axes: xlabel='gender', ylabel='exam_score'>

# %% [markdown]
# Conclusion: All genders tend to get the same scores in exams

# %% [markdown]
# ## Dropout risk between mental issues

# %%
from scipy.stats import pointbiserialr

mental_health_related=df[["mental_health_rating","stress_level","exam_anxiety_score", "dropout_risk"]]

# Variables continuas
continuous_vars = ["mental_health_rating", "stress_level", "exam_anxiety_score"]

# Correlación point biserial con dropout_risk
for var in continuous_vars:
    r, p = pointbiserialr(
        (mental_health_related["dropout_risk"] == "Yes").astype(int),
        mental_health_related[var]
    )
    print(f"{var} vs dropout_risk: r = {r:.3f}, p-value = {p:.3f}")
# Out:
# mental_health_rating vs dropout_risk: r = -0.058, p-value = 0.000
# stress_level vs dropout_risk: r = 0.282, p-value = 0.000
# exam_anxiety_score vs dropout_risk: r = 0.118, p-value = 0.000

# %%
sns.boxplot(x="dropout_risk", y="stress_level", data=mental_health_related, hue="dropout_risk", palette="flare")
plt.show()

# %% [markdown]
# Conclusion
#
# | Variable                                        | r (correlación) | p-valor | Interpretación                                                                                                                                                                                                                      |
# | :---------------------------------------------- | :-------------- | :------ | :---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | **mental\_health\_rating** vs **dropout\_risk** | **-0.058**      | 0.000   | Correlación **negativa muy débil**. A medida que aumenta el rating de salud mental, baja levemente la probabilidad de dropout. Aunque es estadísticamente significativa (por el p-valor), la fuerza de la relación es despreciable. |
# | **stress\_level** vs **dropout\_risk**          | **0.282**       | 0.000   | Correlación **positiva débil-moderada**. A mayor nivel de estrés, **mayor probabilidad de dropout**. Es estadísticamente significativa y relevante a nivel descriptivo.                                                             |
# | **exam\_anxiety\_score** vs **dropout\_risk**   | **0.118**       | 0.000   | Correlación **positiva débil**. A mayor ansiedad en exámenes, **mayor probabilidad de dropout**, aunque la relación es más leve que con el estrés.                                                                                  |

# %% [markdown]
# ## Phone time related:

# %%
phone_score_relation = df[["study_hours_per_day","social_media_hours", "netflix_hours", "screen_time", "previous_gpa","exam_score"]]

sns.pairplot(data=phone_score_relation, hue="exam_score", palette="Oranges", plot_kws={"alpha":0.5})

# %%
corr = phone_score_relation.corr()
sns.heatmap(corr, annot=True, cmap="Oranges")
# Out:
# <Axes: >

# %% [markdown]
# Conclusion: There is no relation between phone time and exam_score

# %%
#sns.pairplot(data=df, hue="gender", palette="Oranges")
# Out:
# Error in callback <function _draw_all_if_interactive at 0x7fc31ab5c720> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/.local/lib/python3.13/site-packages/matplotlib/pyplot.py:279, in _draw_all_if_interactive()
#     277 def _draw_all_if_interactive() -> None:
#     278     if matplotlib.is_interactive():
# --> 279         draw_all()
#
# File ~/.local/lib/python3.13/site-packages/matplotlib/_pylab_helpers.py:131, in Gcf.draw_all(cls, force)
#     129 for manager in cls.get_all_fig_managers():
#     130     if force or manager.canvas.figure.stale:
# --> 131         manager.canvas.draw_idle()
#
# File ~/.local/lib/python3.13/site-packages/matplotlib/backend_bases.py:1891, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1889 if not self._is_idle_drawing:
#    1890     with self._idle_draw_cntx():
# ...

# %% [markdown]
# social_media_hours, netflix_hours, screen_time: Time spent on various screens.
